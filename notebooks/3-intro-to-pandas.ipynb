# %% [markdown]
# <a href="https://colab.research.google.com/gist/iC0rraxX/a8d4b6c338cc3b5c6d4a348b9e58b23d/3-intro-to-pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # The Pandas Library
#
# [``pandas``](https://pandas.pydata.org/) (which stands for Python Data Analysis Library) is one of the foundational Python data science libraries.
#
# A fun introduction to ``pandas`` for Excel users is [here](https://towardsdatascience.com/intro-to-pandas-for-excel-super-users-dac1b38f12b0).
#
# The first step is to load the ``pandas`` module. We will also be using ``matplotlib`` for plotting, so let's load that as well.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Loading Data
#
# ``pandas`` is used to analyse data. The first thing that we'll want to do is to load data into it. There are a number of ways to do this that we will discuss in the next notebook. For the moment, we will load data from URLs using the [``read_csv``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html) function (the one with 49 parameters).
#
#
# https://drive.google.com/file/d/1bmV3uc9Kaj5fi2uGygPRDcr3dfEZxxl7/view?usp=sharing

# %%
df = pd.read_csv('https://drive.google.com/uc?export=download&id=1bmV3uc9Kaj5fi2uGygPRDcr3dfEZxxl7')

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Setting an Index Column
#
# In most time-series data, we want to view the other columns as functions of time. We can tell ``pandas`` to do this by using the [``set_index``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.set_index.html) function. Before we do this, let's look at ``df``.

# %%
df.head(10)
# Out:
#      Date   <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  \
# 0  192607 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33
# 1  192608 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33
# 2  192609 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09
# 3  192610 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95
# 4  192611 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16
# 5  192612 -99.99   2.54    1.69   3.25   1.19   3.78   1.32   2.63   3.14
# 6  192701 -99.99   1.86    1.32   0.23   2.61   1.26   0.74   1.22  -0.08
# 7  192702 -99.99   6.45    6.62   4.17   7.03   5.68   6.83   5.34   4.28
# 8  192703 -99.99  -3.06   -1.93  -0.61  -3.70  -1.52  -3.26  -1.09   0.19
# 9  192704 -99.99   3.48   -0.15   0.05   4.85   0.02   0.11  -0.16   0.14
#
#    Lo 10  2-Dec  3-Dec  4-Dec  5-Dec  6-Dec  7-Dec  8-Dec  9-Dec  Hi 10
# 0  -1.45   0.29  -0.15   1.33   1.24   1.98   1.55   1.38   3.38   3.29
# ...

# %%
df.tail()
# Out:
#         Date   <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  \
# 1119  201910 -99.99  -1.16    2.25   1.21  -1.67   2.38   2.19   0.73   1.48
# 1120  201911 -99.99   3.45    4.38   4.45   2.76   5.62   4.56   4.95   3.87
# 1121  201912 -99.99   6.62    3.29   2.47   6.68   5.46   2.74   2.46   2.60
# 1122  202001 -99.99  -0.90   -3.32  -0.59   0.11  -5.50  -3.18  -1.12  -0.64
# 1123  202002 -99.99  -6.22   -9.19  -8.38  -5.70  -9.60  -8.75  -8.94  -7.97
#
#       Lo 10  2-Dec  3-Dec  4-Dec  5-Dec  6-Dec  7-Dec  8-Dec  9-Dec  Hi 10
# 1119  -2.69   0.97   1.51   3.32   2.87   1.39   0.75   0.70   0.62   2.39
# 1120   1.30   6.54   7.07   4.08   4.65   4.45   4.41   5.56   3.98   3.75
# 1121   6.40   7.40   6.32   4.56   2.82   2.66   2.67   2.22   2.63   2.57
# 1122   2.37  -5.61  -6.29  -4.66  -3.40  -2.92  -1.68  -0.50  -0.66  -0.61
# 1123  -4.90  -7.75  -9.02 -10.21  -8.17  -9.42  -8.74  -9.17  -7.85  -8.10

# %%
df
# Out:
#         Date   <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  \
# 0     192607 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33
# 1     192608 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33
# 2     192609 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09
# 3     192610 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95
# 4     192611 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16
# ...      ...    ...    ...     ...    ...    ...    ...    ...    ...    ...
# 1119  201910 -99.99  -1.16    2.25   1.21  -1.67   2.38   2.19   0.73   1.48
# 1120  201911 -99.99   3.45    4.38   4.45   2.76   5.62   4.56   4.95   3.87
# 1121  201912 -99.99   6.62    3.29   2.47   6.68   5.46   2.74   2.46   2.60
# 1122  202001 -99.99  -0.90   -3.32  -0.59   0.11  -5.50  -3.18  -1.12  -0.64
# 1123  202002 -99.99  -6.22   -9.19  -8.38  -5.70  -9.60  -8.75  -8.94  -7.97
#
# ...

# %% [markdown]
# Note that when we call ``set_index``, we use the optional parameter ``inplace=True`` to specify that we want ``df`` to be changed. If we didn't specify this, then the function would create a new ``DataFrame``, and leave ``df`` unchanged.

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#          <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  Lo 10  \
# Date
# 192607 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33  -1.45
# 192608 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33   5.12
# 192609 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09   0.93
# 192610 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95  -4.84
# 192611 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16  -0.78
# ...       ...    ...     ...    ...    ...    ...    ...    ...    ...    ...
# 201910 -99.99  -1.16    2.25   1.21  -1.67   2.38   2.19   0.73   1.48  -2.69
# 201911 -99.99   3.45    4.38   4.45   2.76   5.62   4.56   4.95   3.87   1.30
# 201912 -99.99   6.62    3.29   2.47   6.68   5.46   2.74   2.46   2.60   6.40
# 202001 -99.99  -0.90   -3.32  -0.59   0.11  -5.50  -3.18  -1.12  -0.64   2.37
# 202002 -99.99  -6.22   -9.19  -8.38  -5.70  -9.60  -8.75  -8.94  -7.97  -4.90
#
# ...

# %% [markdown]
# # Converting Date/Time types
#
# Let's look at the ``Date`` column

# %%
df.index
# Out:
# Int64Index([192607, 192608, 192609, 192610, 192611, 192612, 192701, 192702,
#             192703, 192704,
#             ...
#             201905, 201906, 201907, 201908, 201909, 201910, 201911, 201912,
#             202001, 202002],
#            dtype='int64', name='Date', length=1124)

# %% [markdown]
# Note the line that says ``dtype: int64``. We know that it is a list of dates. We can tell ``pandas`` to parse the column as dates using the [``to_datetime``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.to_datetime.html) method, and then assign that now-parsed ``Series`` to the ``Date`` column.

# %%
df.index = pd.to_datetime(df.index, format="%Y%m")
df.index
# Out:
# DatetimeIndex(['1926-07-01', '1926-08-01', '1926-09-01', '1926-10-01',
#                '1926-11-01', '1926-12-01', '1927-01-01', '1927-02-01',
#                '1927-03-01', '1927-04-01',
#                ...
#                '2019-05-01', '2019-06-01', '2019-07-01', '2019-08-01',
#                '2019-09-01', '2019-10-01', '2019-11-01', '2019-12-01',
#                '2020-01-01', '2020-02-01'],
#               dtype='datetime64[ns]', name='Date', length=1124, freq=None)

# %%
df.index = df.index.to_period('M')

# %%
df.index
# Out:
# PeriodIndex(['1926-07', '1926-08', '1926-09', '1926-10', '1926-11', '1926-12',
#              '1927-01', '1927-02', '1927-03', '1927-04',
#              ...
#              '2019-05', '2019-06', '2019-07', '2019-08', '2019-09', '2019-10',
#              '2019-11', '2019-12', '2020-01', '2020-02'],
#             dtype='period[M]', name='Date', length=1124)

# %% [markdown]
# Similarly if we now access a single column, it is listed as a function of time.

# %%
df['Lo 30']
# Out:
# Date
# 1926-07   -0.43
# 1926-08    3.90
# 1926-09   -1.08
# 1926-10   -3.32
# 1926-11   -0.46
#            ...
# 2019-10   -1.16
# 2019-11    3.45
# 2019-12    6.62
# 2020-01   -0.90
# 2020-02   -6.22
# Freq: M, Name: Lo 30, Length: 1124, dtype: float64

# %% [markdown]
# # Displaying a ``DataFrame``
#
# Let's use the ``display`` function to examine the DataFrame.

# %%
display(df)
# Out:
#           <= 0  Lo 30  Med 40  Hi 30  Lo 20  Qnt 2  Qnt 3  Qnt 4  Hi 20  \
# Date
# 1926-07 -99.99  -0.43    1.52   2.68  -0.57   0.59   1.60   1.47   3.33
# 1926-08 -99.99   3.90    3.04   2.09   3.84   3.59   3.71   1.61   2.33
# 1926-09 -99.99  -1.08   -0.54   0.16  -0.48  -1.40   0.00  -0.50  -0.09
# 1926-10 -99.99  -3.32   -3.52  -3.06  -3.29  -4.10  -2.89  -3.36  -2.95
# 1926-11 -99.99  -0.46    3.82   3.09  -0.55   2.18   3.41   3.39   3.16
# ...        ...    ...     ...    ...    ...    ...    ...    ...    ...
# 2019-10 -99.99  -1.16    2.25   1.21  -1.67   2.38   2.19   0.73   1.48
# 2019-11 -99.99   3.45    4.38   4.45   2.76   5.62   4.56   4.95   3.87
# 2019-12 -99.99   6.62    3.29   2.47   6.68   5.46   2.74   2.46   2.60
# 2020-01 -99.99  -0.90   -3.32  -0.59   0.11  -5.50  -3.18  -1.12  -0.64
# 2020-02 -99.99  -6.22   -9.19  -8.38  -5.70  -9.60  -8.75  -8.94  -7.97
#
#          Lo 10  2-Dec  3-Dec  4-Dec  5-Dec  6-Dec  7-Dec  8-Dec  9-Dec  Hi 10
# Date
# ...

# %% [markdown]
# The result is a [``DataFrame``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.html) object. ``DataFrames`` are going to be the main type that we'll be using in this course. It is roughly equivalent to an Excel sheet.

# %% [markdown]
# The [``describe``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.describe.html) function will give statistics for the numerical columns of the ``DataFrame``.

# %%
df.describe()

# %%
display(df)

# %% [markdown]
# # Accessing Columns as Series
#
# The individual columns of a ``DataFrame`` are a data type called a [``Series``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.html). We can list the column names of ``df`` using the [``columns``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.columns.html) property.

# %%
df.columns

# %% [markdown]
# We can access an individual column using the ``[]`` operator and the name of column.

# %%
df['Lo 30']

# %%
df[['Lo 30']]

# %% [markdown]
# And we can use [``describe``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.describe.html) on a ``Series``.

# %%
df[['Lo 30']].describe()

# %% [markdown]
# We can also create a ``DataFrame`` with a subset of the columns by using a list of column names in the ``[]``. For example.

# %%
df[ ['Lo 30', 'Hi 30'] ]

# %% [markdown]
# # Accessing Rows

# %% [markdown]
# We can query an individual row by index using [``loc``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html).

# %%
df.loc['2008-08']

# %% [markdown]
# Or we can access several rows using the ``:`` range syntax.

# %%
 df.loc['2008':'2008']

# %% [markdown]
# # Plotting Data
#
# We can use the [``plot``](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.html) method to plot either the full ``DataFrame`` or a single series. After calling ``plot``, we will need to call ``matplotlib``'s [``show``](https://matplotlib.org/api/_as_gen/matplotlib.pyplot.show.html) method.

# %%
df.plot()
plt.show()

# %% [markdown]
# Note that the $x$ axis is the date. This is because we set the index column to be ``Date``.
#
# We can also plot an individual column.

# %%
df['Hi 30'].plot()
plt.show()
